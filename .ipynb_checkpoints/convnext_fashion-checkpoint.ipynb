# %% [markdown]
# # ConvNeXt on FashionMNIST
#
# ## Setup

# %%
import torch
import torch.nn as nn
import timm
import semitorch
from torchvision import transforms
from torchvision.datasets import FashionMNIST
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import gc
import numpy as np
from IPython import display

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"device = {device}")

convnext_atto = timm.create_model("convnext_atto", in_chans=1)
convnext_atto.stem[0] = nn.Conv2d(1, 40, kernel_size=(1,1))

convnext_atto = convnext_atto.to(device)

num_params = sum(p.numel() for p in convnext_atto.parameters() if p.requires_grad)
print(f"convnext_att has {num_params:,} parameters")
# Out:
# [Taichi] version 1.5.0, llvm 15.0.4, commit 7b885c28, linux, python 3.10.10
# [I 06/14/23 09:46:34.790 18314] [shell.py:_shell_pop_print@23] Graphical python shell detected, using wrapped sys.stdout
# [Taichi] Starting on arch=cuda
# device = cuda
# convnext_att has 3,693,640 parameters

# %%
# Load FashionMNIST dataset
batch_size = 256
num_workers = 8

transforms_train = transforms.Compose(
    [
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
    ]
)

transforms_test = transforms.Compose(
    [
        transforms.ToTensor(),
    ]
)

trainset = FashionMNIST(root=".", train=True, download=True, transform=transforms_train)
testset = FashionMNIST(root=".", train=False, download=True, transform=transforms_test)

trainloader = DataLoader(
    trainset, batch_size=batch_size, shuffle=True, num_workers=num_workers
)
testloader = DataLoader(
    testset, batch_size=batch_size, shuffle=False, num_workers=num_workers
)

# %% [markdown]
# ## Training
#
# We train the network with SGD+momentum under the [one cycle policy](https://arxiv.org/abs/1708.07120).
# As usual we use cross entropy loss.
# To track the track the training process we plot the accuracy of each training batch as a blue dot, every epoch we also test the network and the training data and plot the network's accuracy as an orange line.

# %%
def accuracy(model, x, y):
    with torch.no_grad():
        yout = model(x)
        _, prediction = torch.max(yout.cpu(), dim=1)
        return (y==prediction).sum().item() / float(y.numel())



def test(model, device, testloader):
    model.eval()
    accs = []
    with torch.no_grad():
        for x, y in testloader:
            x = x.to(device)
            accs.append(accuracy(model, x, y))
    return sum(accs)/len(accs)


def train(model, device, trainloader, testloader, optimizer, scheduler, loss, epochs):
    accs = [] # list of accuracy on the test dataset for every epoch
    trainaccs = [] # a list of the accuracies of all the training batches
    for epoch in range(epochs):
        model.train()
        for x, y in trainloader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            yout = model(x)
            _, prediction = torch.max(yout.cpu(), dim=1)
            trainaccs.append((y.cpu()==prediction).sum().item() / float(y.numel()))
            l = loss(yout, y)
            l.backward()
            optimizer.step()
            scheduler.step()

        accs.append(test(model, device, testloader))
        clear_output(wait=True)
        plt.figure(figsize=[6,4])
        plt.xlim(0,epochs)
        plt.ylim(0.7,1)
        plt.plot(np.linspace(0,len(accs),len(trainaccs)), 
            trainaccs, ".", markersize=1.5, markerfacecolor=(0, 0, 1, 0.3))
        plt.plot(np.linspace(1,len(accs),len(accs)), accs)
        plt.text(0.6*epochs, 0.75, f"max test acc = {max(accs):.2%}", ha="center", fontsize=10)
        plt.show()
        
        # prevents OOM when GPU memory is tight
        torch.cuda.empty_cache()
        gc.collect()
        

def resetmodel(model: nn.Module) -> None:
    @torch.no_grad()
    def weight_reset(m: nn.Module):
        reset_parameters = getattr(m, "reset_parameters", None)
        if callable(reset_parameters):
            m.reset_parameters()
    model.apply(fn=weight_reset)

# %%
resetmodel(convnext_atto)

# %%
loss = nn.CrossEntropyLoss()
epochs = 50

optimizer = torch.optim.AdamW(convnext_atto.parameters(), 
                lr=1e-2,
                weight_decay=0.01
            )
scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, 
                max_lr=1e-2,
                anneal_strategy='linear',
                pct_start=0.4,
                three_phase=True,
                final_div_factor=500.0,
                div_factor=25.0,
                steps_per_epoch=len(trainloader), 
                epochs=epochs
            )

train(convnext_atto, device, trainloader, testloader, optimizer, scheduler, loss, epochs)

# %%
# save layer names
layer_names = []
for idx, (name, param) in enumerate(convnext_atto.named_parameters()):
    layer_names.append(name)
    print(f'{idx}: {name}')
# Out:
# 0: stem.0.weight
# 1: stem.0.bias
# 2: stem.1.weight
# 3: stem.1.bias
# 4: stages.0.blocks.0.gamma
# 5: stages.0.blocks.0.conv_dw.weight
# 6: stages.0.blocks.0.conv_dw.bias
# 7: stages.0.blocks.0.norm.weight
# 8: stages.0.blocks.0.norm.bias
# 9: stages.0.blocks.0.mlp.fc1.weight
# 10: stages.0.blocks.0.mlp.fc1.bias
# 11: stages.0.blocks.0.mlp.fc2.weight
# 12: stages.0.blocks.0.mlp.fc2.bias
# 13: stages.0.blocks.1.gamma
# 14: stages.0.blocks.1.conv_dw.weight
# 15: stages.0.blocks.1.conv_dw.bias
# 16: stages.0.blocks.1.norm.weight
# 17: stages.0.blocks.1.norm.bias
# 18: stages.0.blocks.1.mlp.fc1.weight
# 19: stages.0.blocks.1.mlp.fc1.bias
# 20: stages.0.blocks.1.mlp.fc2.weight
# 21: stages.0.blocks.1.mlp.fc2.bias
# 22: stages.1.downsample.0.weight
# 23: stages.1.downsample.0.bias
# 24: stages.1.downsample.1.weight
# 25: stages.1.downsample.1.bias
# 26: stages.1.blocks.0.gamma
# 27: stages.1.blocks.0.conv_dw.weight
# 28: stages.1.blocks.0.conv_dw.bias
# 29: stages.1.blocks.0.norm.weight
# 30: stages.1.blocks.0.norm.bias
# 31: stages.1.blocks.0.mlp.fc1.weight
# 32: stages.1.blocks.0.mlp.fc1.bias
# 33: stages.1.blocks.0.mlp.fc2.weight
# 34: stages.1.blocks.0.mlp.fc2.bias
# 35: stages.1.blocks.1.gamma
# 36: stages.1.blocks.1.conv_dw.weight
# 37: stages.1.blocks.1.conv_dw.bias
# 38: stages.1.blocks.1.norm.weight
# 39: stages.1.blocks.1.norm.bias
# 40: stages.1.blocks.1.mlp.fc1.weight
# 41: stages.1.blocks.1.mlp.fc1.bias
# 42: stages.1.blocks.1.mlp.fc2.weight
# 43: stages.1.blocks.1.mlp.fc2.bias
# 44: stages.2.downsample.0.weight
# 45: stages.2.downsample.0.bias
# 46: stages.2.downsample.1.weight
# 47: stages.2.downsample.1.bias
# 48: stages.2.blocks.0.gamma
# 49: stages.2.blocks.0.conv_dw.weight
# 50: stages.2.blocks.0.conv_dw.bias
# 51: stages.2.blocks.0.norm.weight
# 52: stages.2.blocks.0.norm.bias
# 53: stages.2.blocks.0.mlp.fc1.weight
# 54: stages.2.blocks.0.mlp.fc1.bias
# 55: stages.2.blocks.0.mlp.fc2.weight
# 56: stages.2.blocks.0.mlp.fc2.bias
# 57: stages.2.blocks.1.gamma
# 58: stages.2.blocks.1.conv_dw.weight
# 59: stages.2.blocks.1.conv_dw.bias
# 60: stages.2.blocks.1.norm.weight
# 61: stages.2.blocks.1.norm.bias
# 62: stages.2.blocks.1.mlp.fc1.weight
# 63: stages.2.blocks.1.mlp.fc1.bias
# 64: stages.2.blocks.1.mlp.fc2.weight
# 65: stages.2.blocks.1.mlp.fc2.bias
# 66: stages.2.blocks.2.gamma
# 67: stages.2.blocks.2.conv_dw.weight
# 68: stages.2.blocks.2.conv_dw.bias
# 69: stages.2.blocks.2.norm.weight
# 70: stages.2.blocks.2.norm.bias
# 71: stages.2.blocks.2.mlp.fc1.weight
# 72: stages.2.blocks.2.mlp.fc1.bias
# 73: stages.2.blocks.2.mlp.fc2.weight
# 74: stages.2.blocks.2.mlp.fc2.bias
# 75: stages.2.blocks.3.gamma
# 76: stages.2.blocks.3.conv_dw.weight
# 77: stages.2.blocks.3.conv_dw.bias
# 78: stages.2.blocks.3.norm.weight
# 79: stages.2.blocks.3.norm.bias
# 80: stages.2.blocks.3.mlp.fc1.weight
# 81: stages.2.blocks.3.mlp.fc1.bias
# 82: stages.2.blocks.3.mlp.fc2.weight
# 83: stages.2.blocks.3.mlp.fc2.bias
# 84: stages.2.blocks.4.gamma
# 85: stages.2.blocks.4.conv_dw.weight
# 86: stages.2.blocks.4.conv_dw.bias
# 87: stages.2.blocks.4.norm.weight
# 88: stages.2.blocks.4.norm.bias
# 89: stages.2.blocks.4.mlp.fc1.weight
# 90: stages.2.blocks.4.mlp.fc1.bias
# 91: stages.2.blocks.4.mlp.fc2.weight
# 92: stages.2.blocks.4.mlp.fc2.bias
# 93: stages.2.blocks.5.gamma
# 94: stages.2.blocks.5.conv_dw.weight
# 95: stages.2.blocks.5.conv_dw.bias
# 96: stages.2.blocks.5.norm.weight
# 97: stages.2.blocks.5.norm.bias
# 98: stages.2.blocks.5.mlp.fc1.weight
# 99: stages.2.blocks.5.mlp.fc1.bias
# 100: stages.2.blocks.5.mlp.fc2.weight
# 101: stages.2.blocks.5.mlp.fc2.bias
# 102: stages.3.downsample.0.weight
# 103: stages.3.downsample.0.bias
# 104: stages.3.downsample.1.weight
# 105: stages.3.downsample.1.bias
# 106: stages.3.blocks.0.gamma
# 107: stages.3.blocks.0.conv_dw.weight
# 108: stages.3.blocks.0.conv_dw.bias
# 109: stages.3.blocks.0.norm.weight
# 110: stages.3.blocks.0.norm.bias
# 111: stages.3.blocks.0.mlp.fc1.weight
# 112: stages.3.blocks.0.mlp.fc1.bias
# 113: stages.3.blocks.0.mlp.fc2.weight
# 114: stages.3.blocks.0.mlp.fc2.bias
# 115: stages.3.blocks.1.gamma
# 116: stages.3.blocks.1.conv_dw.weight
# 117: stages.3.blocks.1.conv_dw.bias
# 118: stages.3.blocks.1.norm.weight
# 119: stages.3.blocks.1.norm.bias
# 120: stages.3.blocks.1.mlp.fc1.weight
# 121: stages.3.blocks.1.mlp.fc1.bias
# 122: stages.3.blocks.1.mlp.fc2.weight
# 123: stages.3.blocks.1.mlp.fc2.bias
# 124: head.norm.weight
# 125: head.norm.bias
# 126: head.fc.weight
# 127: head.fc.bias
